# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"D:\Workshop_AI_CODE\data\Test_Data.xlsx")

# %%
#Display The Data
mydata
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
#Display Top 5 Rows Data 
mydata.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
#Display Bottom 5 Rows Data
mydata.tail()
# Out:
#     account                          name                     street  \
# 10   214098   Goodwin, Homenick and Jerde  649 Cierra Forks Apt. 078
# 11   231907                    Hahn-Moore   18115 Olivine Throughway
# 12   242368  Frami, Anderson and Donnelly            182 Bertie Road
# 13   268755                   Walsh-Haley       2624 Beatty Parkways
# 14   273274                 McDermott PLC      8917 Bergstrom Meadow
#
#                city        state  postal-code     Jan     Feb     Mar
# 10         Rosaberg     Tenessee        47743   45000  120000   55000
# 11    Norbertomouth  NorthDakota        31415  150000   10000  162000
# 12      East Davian         Iowa        72686  162000  120000   35000
# 13     Goodwinmouth  RhodeIsland        31919   55000  120000   35000
# 14  Kathryneborough     Delaware        27933  150000  120000   70000

# %%
#Display the index
mydata.index
#dispay row and column
row,column=mydata.shape
#display all key 
mydata.keys()
#description 
mydata.describe()
#dispaly information 
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
# account        15 non-null int64
# name           15 non-null object
# street         15 non-null object
# city           15 non-null object
# state          15 non-null object
# postal-code    15 non-null int64
# Jan            15 non-null int64
# Feb            15 non-null int64
# Mar            15 non-null int64
# dtypes: int64(5), object(4)
# memory usage: 1.1+ KB

# %%
# Extrating Jan Column
mydata["Jan"]
mydata.Jan 
mydata.iloc[:,6]
# Out:
# 0      10000
# 1      95000
# 2      91000
# 3      45000
# 4     162000
# 5     150000
# 6      62000
# 7     145000
# 8      70000
# 9      70000
# 10     45000
# 11    150000
# 12    162000
# 13     55000
# 14    150000
# Name: Jan, dtype: int64

# %%
# Extrating First Row
mydata.iloc[0]
# Out:
# account                            211829
# name           Kerluke, Koepp and Hilpert
# street                 34456 Sean Highway
# city                           New Jaycob
# state                               Texas
# postal-code                         28752
# Jan                                 10000
# Feb                                 62000
# Mar                                 35000
# Name: 0, dtype: object

# %%
# Extracting Account Jan
mydata[["account","Jan"]]
# Out:
#     account     Jan
# 0    211829   10000
# 1    320563   95000
# 2    648336   91000
# 3    109996   45000
# 4    121213  162000
# 5    132971  150000
# 6    145068   62000
# 7    205217  145000
# 8    209744   70000
# 9    212303   70000
# 10   214098   45000
# 11   231907  150000
# 12   242368  162000
# 13   268755   55000
# 14   273274  150000

# %%
# adding new Col Total=Jan+Feb+Mar
mydata["Total"]=mydata["Jan"]+mydata["Feb"]+mydata["Mar"]

# %%
#Displaying the First Row
mydata.head(1)
# Out:
#    account                        name              street        city  state  \
# 0   211829  Kerluke, Koepp and Hilpert  34456 Sean Highway  New Jaycob  Texas
#
#    postal-code    Jan    Feb    Mar   Total
# 0        28752  10000  62000  35000  107000

# %%
#Maxmimum Value in Jan
mydata["Jan"].max()
# Out:
# 162000

# %%
#Sum of  Jan
mydata["Jan"].sum()
# Out:
# 1462000
